# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("bestV3-OBB.pt")

# Run inference on the source
results = model('77_Color.png')  # generator of Results objects

for r in results:
    print(r.obb)
# Out:
# image 1/1 c:\Users\frost\Downloads\work_final\T.A\77_Color.png: 384x640 80.7ms
# Speed: 0.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ultralytics.engine.results.OBB object with attributes:
#
# cls: tensor([0., 0., 0., 2., 1., 2., 1., 1., 0., 2., 0., 0.])
# conf: tensor([0.9571, 0.9510, 0.9477, 0.9466, 0.9380, 0.9329, 0.9301, 0.9296, 0.9272, 0.9181, 0.9079, 0.7413])
# data: tensor([[6.6611e+02, 3.4962e+02, 5.3493e+01, 2.1394e+01, 1.1223e+00, 9.5709e-01, 0.0000e+00],
#         [6.0657e+02, 3.8036e+02, 5.1819e+01, 2.4776e+01, 2.7221e-01, 9.5099e-01, 0.0000e+00],
#         [5.2642e+02, 4.0008e+02, 5.2605e+01, 2.6680e+01, 4.3992e-01, 9.4775e-01, 0.0000e+00],
#         [5.8619e+02, 3.0049e+02, 5.0975e+01, 2.1161e+01, 2.2342e-01, 9.4664e-01, 2.0000e+00],
#         [4.8179e+02, 1.5852e+02, 6.3402e+01, 2.8666e+01, 2.7086e+00, 9.3797e-01, 1.0000e+00],
#         [6.2924e+02, 4.7231e+02, 5.1618e+01, 2.3408e+01, 2.7772e-01, 9.3291e-01, 2.0000e+00],
# ...
